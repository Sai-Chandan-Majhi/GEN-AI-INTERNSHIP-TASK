# %%
username=input()
password=input()


if username=='admin' and password=='1234':
    print('Login Successful')
else:
    print('Invalid Credentials')
# Out:
# admin
# 1234
# Login Successful

# %%
marks=[45,78,90,30,60]
a=[]
for i in marks:
    if i>50:
        a.append(i)
print(f'The total number of Students are pass {len(a)} and {len(marks)-len(a)} Fails')
# Out:
# The total number of Students are pass 3 and 2 Fails

# %%
names = [" Alice ", "bob", " CHARLIE "]

a=[]
for i in names:
    a.append(i.strip().lower())
print(a)
# Out:
# ['alice', 'bob', 'charlie']

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for i in messages:
    if len(i)>10:
        print(f'{i} ({len(i)}) - Flag Message')
    else:
         print(f'{i} ({len(i)}) - Not Flag Message')
# Out:
# Hi (2) - Not Flag Message
# Welcome to the platform (23) - Flag Message
# OK (2) - Not Flag Message

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
count=0
for i in logs:
    if i=='ERROR':
        count=count+1
print(count)
# Out:
# 2
